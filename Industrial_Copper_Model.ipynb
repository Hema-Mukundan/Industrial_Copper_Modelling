# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('/content/Copper_Set.xlsx - Result 1.csv')

# %% [markdown]
# # Basic information about the dataset

# %%
df.head()
# Out:
#                                      id  item_date  quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE   20210401      54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425   20210401     768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158   20210401     386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50   20210401     202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD   20210401     785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref   product_ref  delivery date  \
# 0                               DEQ1 S460MC  1.670799e+09     20210701.0
# 1  0000000000000000000000000000000000104991  1.668702e+09     20210401.0
# 2                                  S0380700  6.283770e+05     20210101.0
# 3                   DX51D+ZM310MAO 2.3X1317  1.668702e+09     20210101.0
# 4                           2_S275JR+AR-CL1  6.406650e+05     20210301.0
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
df.columns
# Out:
# Index(['id', 'item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'delivery date', 'selling_price'],
#       dtype='object')

# %% [markdown]
# # Checking unique value counts in each column

# %%
df.nunique()
# Out:
# id               33539
# item_date           37
# quantity tons    33540
# customer           794
# country             16
# status               8
# item type            6
# application         29
# thickness          416
# width             1030
# material_ref      7827
# product_ref         29
# delivery date       21
# selling_price     2887
# dtype: int64

# %% [markdown]
# ## Check data types

# %%
df.dtypes
# Out:
# id                object
# item_date          int64
# quantity tons    float64
# customer         float64
# country          float64
# status            object
# item type         object
# application      float64
# thickness        float64
# width            float64
# material_ref      object
# product_ref      float64
# delivery date    float64
# selling_price    float64
# dtype: object

# %% [markdown]
# # Converting object data type to numeric

# %%
df['quantity tons'] = pd.to_numeric(df['quantity tons'], errors='coerce')

# %%
df['item_date'] = pd.to_datetime(df['item_date'], format='%Y%m%d',errors='coerce')

# %%
df['delivery date'] = pd.to_datetime(df['delivery date'], format='%Y%m%d',errors='coerce')

# %%
df.head(3)
# Out:
#                                      id  item_date  quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949  30153963.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
#
#                                material_ref   product_ref delivery date  \
# 0                               DEQ1 S460MC  1.670799e+09    2021-07-01
# 1  0000000000000000000000000000000000104991  1.668702e+09    2021-04-01
# 2                                  S0380700  6.283770e+05    2021-01-01
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33

# %% [markdown]
# # Replacing '00000' with NaN in Material_Ref column

# %%
df.loc[df['material_ref'].astype(str).str.startswith('00000'), 'material_ref'] = np.nan
df.head()
# Out:
#                                      id  item_date  quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#               material_ref   product_ref delivery date  selling_price
# 0              DEQ1 S460MC  1.670799e+09    2021-07-01         854.00
# 1                      NaN  1.668702e+09    2021-04-01        1047.00
# 2                 S0380700  6.283770e+05    2021-01-01         644.33
# 3  DX51D+ZM310MAO 2.3X1317  1.668702e+09    2021-01-01         768.00
# 4          2_S275JR+AR-CL1  6.406650e+05    2021-03-01         577.00

# %% [markdown]
# # Check for null values

# %%
df.isnull().sum()
# Out:
# id                   1
# item_date            1
# quantity tons        0
# customer             1
# country              1
# status               1
# item type            1
# application          1
# thickness            1
# width                1
# material_ref     18645
# product_ref          1
# delivery date        2
# selling_price        1
# dtype: int64

# %% [markdown]
# # Drop columns 'id'(unique values) and 'material_ref'(more than 50% null values)

# %%
df.drop(columns=['id','material_ref'], inplace=True)
df
# Out:
#        item_date  quantity tons    customer  country   status item type  \
# 0     2021-04-01      54.151139  30156308.0     28.0      Won         W
# 1     2021-04-01     768.024839  30202938.0     25.0      Won         W
# 2     2021-04-01     386.127949  30153963.0     30.0      Won        WI
# 3     2021-04-01     202.411065  30349574.0     32.0      Won         S
# 4     2021-04-01     785.526262  30211560.0     28.0      Won         W
# ...          ...            ...         ...      ...      ...       ...
# 33535 2021-02-23      21.790137  30161540.0     77.0      Won         W
# 33536 2021-02-23     750.252104  30199179.0     26.0  Revised        PL
# 33537 2021-02-23     308.938412  30160005.0     78.0      Won         W
# 33538 2021-02-23     754.754355  30199179.0     26.0  Revised        PL
# 33539 2021-02-23      16.000000         NaN      NaN      NaN       NaN
#
#        application  thickness   width   product_ref delivery date  \
# 0             10.0       2.00  1500.0  1.670799e+09    2021-07-01
# 1             41.0       0.80  1210.0  1.668702e+09    2021-04-01
# 2             28.0       0.38   952.0  6.283770e+05    2021-01-01
# 3             59.0       2.30  1317.0  1.668702e+09    2021-01-01
# 4             10.0       4.00  2000.0  6.406650e+05    2021-03-01
# ...            ...        ...     ...           ...           ...
# 33535         15.0       1.80   865.0  1.670799e+09    2021-04-01
# 33536         10.0       0.75  1121.0  6.283770e+05    2021-07-01
# 33537         41.0       3.00  1500.0  6.406650e+05    2021-04-01
# 33538         10.0       0.51  1286.0  6.283770e+05    2021-07-01
# 33539          NaN        NaN     NaN           NaN           NaT
#
#        selling_price
# 0             854.00
# 1            1047.00
# 2             644.33
# 3             768.00
# 4             577.00
# ...              ...
# 33535         887.00
# 33536         904.00
# 33537         795.00
# 33538         971.00
# 33539            NaN
#
# [33540 rows x 12 columns]

# %%
df.describe()
# Out:
#        quantity tons      customer       country   application     thickness  \
# count   33540.000000  3.353900e+04  33539.000000  33539.000000  33539.000000
# mean       96.964033  3.023760e+07     43.388294     25.938162      2.653904
# std       421.055329  7.193730e+04     23.753682     18.096497     13.897425
# min         0.006311  3.014762e+07     25.000000      2.000000      0.180000
# 25%        11.327948  3.019726e+07     26.000000     10.000000      0.750000
# 50%        30.938335  3.020582e+07     28.000000     15.000000      1.500000
# 75%        66.633373  3.028726e+07     77.000000     41.000000      3.000000
# max     20300.293590  3.040818e+07    113.000000     99.000000   2500.000000
#
#               width   product_ref  selling_price
# count  33539.000000  3.353900e+04   3.353900e+04
# mean    1303.415647  5.238775e+08   3.962283e+03
# std      252.777574  7.421499e+08   5.460404e+05
# min        1.000000  6.117280e+05  -1.160000e+03
# 25%     1187.500000  6.283770e+05   8.780000e+02
# 50%     1250.000000  6.406650e+05   9.720000e+02
# 75%     1500.000000  1.668702e+09   1.090000e+03
# max     2150.000000  1.722208e+09   1.000009e+08

# %%
# we see negative number in both columns 'quantity tons' and 'selling_price'
df['quantity tons'] = df['quantity tons'].apply(lambda x: np.nan if x<=0 else x)
df['selling_price'] = df['selling_price'].apply(lambda x: np.nan if x<=0 else x)
df.describe()
# Out:
#        quantity tons      customer       country   application     thickness  \
# count   33540.000000  3.353900e+04  33539.000000  33539.000000  33539.000000
# mean       96.964033  3.023760e+07     43.388294     25.938162      2.653904
# std       421.055329  7.193730e+04     23.753682     18.096497     13.897425
# min         0.006311  3.014762e+07     25.000000      2.000000      0.180000
# 25%        11.327948  3.019726e+07     26.000000     10.000000      0.750000
# 50%        30.938335  3.020582e+07     28.000000     15.000000      1.500000
# 75%        66.633373  3.028726e+07     77.000000     41.000000      3.000000
# max     20300.293590  3.040818e+07    113.000000     99.000000   2500.000000
#
#               width   product_ref  selling_price
# count  33539.000000  3.353900e+04   3.353700e+04
# mean    1303.415647  5.238775e+08   3.962554e+03
# std      252.777574  7.421499e+08   5.460567e+05
# min        1.000000  6.117280e+05   1.100000e+01
# 25%     1187.500000  6.283770e+05   8.780000e+02
# 50%     1250.000000  6.406650e+05   9.720000e+02
# 75%     1500.000000  1.668702e+09   1.090000e+03
# max     2150.000000  1.722208e+09   1.000009e+08

# %%
# check null values for all features
df.isnull().sum()
# Out:
# item_date        1
# quantity tons    0
# customer         1
# country          1
# status           1
# item type        1
# application      1
# thickness        1
# width            1
# product_ref      1
# delivery date    2
# selling_price    3
# dtype: int64
